# %%
pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 95.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.1 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=351fc3facaf50ee4f1880c3524974b38aa05b61e674ad731a26c1700a716fae7
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
img1=cv2.imread('/content/My Pic.jpg')
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img1,actions=['emotion'])
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.24it/s]

# %%
import pprint
pprint.pprint(result)
# Out:
# [{'dominant_emotion': 'happy',
#   'emotion': {'angry': 0.011073285713791847,
#               'disgust': 1.7110342656612154e-09,
#               'fear': 3.51935513317585,
#               'happy': 74.20617938041687,
#               'neutral': 22.12698757648468,
#               'sad': 0.10299888672307134,
#               'surprise': 0.0334017415298149},
#   'region': {'h': 367, 'w': 367, 'x': 218, 'y': 651}}]

# %%
function extractFeatures(aligned_faces):
    // Use a deep neural network to extract high-dimensional features from the aligned faces
    // Return the extracted features

function classifyFaces(face_features):
    // Use a trained deep neural network classifier to predict identities or attributes
    // Return the predictions for each face

function calculateSimilarity(predictions):
    // Calculate the distance or similarity metric between the feature vectors of different faces
    // Return the similarity scores

function verifyFaces(similarity_scores):
    // Compare the similarity scores against a predefined threshold
    // Return True if the faces belong to the same person, False otherwise

function recognizeFace(similarity_scores, known_faces_database):
    // Match the face against a database of known faces using the similarity scores
    // Return the recognized person's identity or None if not found
